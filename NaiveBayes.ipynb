# %% [markdown]
# <a href="https://colab.research.google.com/github/shreyaadarakh/NLPsem6/blob/master/NaiveBayes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split as tts
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.naive_bayes import GaussianNB

# %%
df = pd.read_csv("UCI_Credit_Card.csv")

# %%
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  ...  PAY_AMT5  PAY_AMT6  default.payment.next.month
# 0   1    20000.0    2  ...       0.0       0.0                           1
# 1   2   120000.0    2  ...       0.0    2000.0                           1
# 2   3    90000.0    2  ...    1000.0    5000.0                           0
# 3   4    50000.0    2  ...    1069.0    1000.0                           0
# 4   5    50000.0    1  ...     689.0     679.0                           0
#
# [5 rows x 25 columns]

# %%
df.isnull().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default.payment.next.month    0
# dtype: int64

# %%
df.describe()
# Out:
#                  ID       LIMIT_BAL  ...       PAY_AMT6  default.payment.next.month
# count  30000.000000    30000.000000  ...   30000.000000                30000.000000
# mean   15000.500000   167484.322667  ...    5215.502567                    0.221200
# std     8660.398374   129747.661567  ...   17777.465775                    0.415062
# min        1.000000    10000.000000  ...       0.000000                    0.000000
# 25%     7500.750000    50000.000000  ...     117.750000                    0.000000
# 50%    15000.500000   140000.000000  ...    1500.000000                    0.000000
# 75%    22500.250000   240000.000000  ...    4000.000000                    0.000000
# max    30000.000000  1000000.000000  ...  528666.000000                    1.000000
#
# [8 rows x 25 columns]

# %%
df.drop(["ID"], axis = 1, inplace = True)

# %%
y = df["default.payment.next.month"]
y
# Out:
# 0        1
# 1        1
# 2        0
# 3        0
# 4        0
#         ..
# 29995    0
# 29996    0
# 29997    1
# 29998    1
# 29999    1
# Name: default.payment.next.month, Length: 30000, dtype: int64

# %%
X = df.drop(["default.payment.next.month"],1)

# %%
x_train,x_test,y_train,y_test = tts(X,y,test_size=0.3, random_state=4)

# %%
model = GaussianNB()
model.fit(x_train,y_train)

# %%
y_pred = model.predict(x_test)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.24      0.37      6969
#            1       0.25      0.88      0.39      2031
#
#     accuracy                           0.38      9000
#    macro avg       0.56      0.56      0.38      9000
# weighted avg       0.73      0.38      0.38      9000

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[1658 5311]
#  [ 244 1787]]
